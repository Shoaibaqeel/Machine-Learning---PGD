# %% [markdown]
# # Assignment 1: Simple Linear Regression Model
# ## Shoaib Aqeel PGD Batch 06

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv("canada_per_capita_income.csv")

# %%
df
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
df_2 = pd.read_csv("years.csv")

# %%
df_2
# Out:
#     year
# 0   1978
# 1   1979
# 2   1980
# 3   1981
# 4   1982
# 5   1992
# 6   1993
# 7   1994
# 8   1995
# 9   1996
# 10  1997
# 11  1998
# 12  1999
# 13  2000
# 14  2001
# 15  2002
# 16  2011
# 17  2012
# 18  2013
# 19  2014
# 20  2015
# 21  2016
# 22  2017
# 23  2018
# 24  2019
# 25  2020
# 26  2021

# %%
x = df.iloc[:,:1]
y = df.iloc[:,1:]

# %%
x
# Out:
#     year
# 0   1970
# 1   1971
# 2   1972
# 3   1973
# 4   1974
# 5   1975
# 6   1976
# 7   1977
# 8   1978
# 9   1979
# 10  1980
# 11  1981
# 12  1982
# 13  1983
# 14  1984
# 15  1985
# 16  1986
# 17  1987
# 18  1988
# 19  1989
# 20  1990
# 21  1991
# 22  1992
# 23  1993
# 24  1994
# 25  1995
# 26  1996
# 27  1997
# 28  1998
# 29  1999
# 30  2000
# 31  2001
# 32  2002
# 33  2003
# 34  2004
# 35  2005
# 36  2006
# 37  2007
# 38  2008
# 39  2009
# 40  2010
# 41  2011
# 42  2012
# 43  2013
# 44  2014
# 45  2015
# 46  2016

# %%
y
# Out:
#     per capita income (US$)
# 0               3399.299037
# 1               3768.297935
# 2               4251.175484
# 3               4804.463248
# 4               5576.514583
# 5               5998.144346
# 6               7062.131392
# 7               7100.126170
# 8               7247.967035
# 9               7602.912681
# 10              8355.968120
# 11              9434.390652
# 12              9619.438377
# 13             10416.536590
# 14             10790.328720
# 15             11018.955850
# 16             11482.891530
# 17             12974.806620
# 18             15080.283450
# 19             16426.725480
# 20             16838.673200
# 21             17266.097690
# 22             16412.083090
# 23             15875.586730
# 24             15755.820270
# 25             16369.317250
# 26             16699.826680
# 27             17310.757750
# 28             16622.671870
# 29             17581.024140
# 30             18987.382410
# 31             18601.397240
# ...

# %%
reg = LinearRegression()

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2, random_state = 40)

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_test = reg.predict(x_test)
y_pred_train = reg.predict(x_train)

# %%
error = y_test - y_pred_test

# %%
error
# Out:
#     per capita income (US$)
# 46             -4296.388026
# 16             -1419.608739
# 35                67.603876
# 42              7556.085165
# 0               4162.442175
# 4               2923.246869
# 26             -4743.700718
# 11               802.403948
# 2               3306.113196
# 28             -6529.060954

# %%
# evaluate the model
print('MSE = ', mean_squared_error(y_test, y_pred_test ))
print('R2 = ', r2_score(y_test, y_pred_test))
print('RMSE = ', np.sqrt(mean_squared_error(y_test, y_pred_test)))
# Out:
# MSE =  18015009.94679724
# R2 =  0.8920606163157566
# RMSE =  4244.409257693848

# %%
print('Model accuracy = ', (r2_score(y_test, y_pred_test))*100,"%")
# Out:
# Model accuracy =  89.20606163157566 %

# %%
print("Y=", reg.intercept_,"+",reg.coef_,"* x")
# Out:
# Y= [-1683345.48756769] + [[854.10271291]] * x

# %%
# Prediction on test set
plt.scatter(x, y, color = 'blue')

# %%
x_predict= df_2

# %%
x_predict
# Out:
#     year
# 0   1978
# 1   1979
# 2   1980
# 3   1981
# 4   1982
# 5   1992
# 6   1993
# 7   1994
# 8   1995
# 9   1996
# 10  1997
# 11  1998
# 12  1999
# 13  2000
# 14  2001
# 15  2002
# 16  2011
# 17  2012
# 18  2013
# 19  2014
# 20  2015
# 21  2016
# 22  2017
# 23  2018
# 24  2019
# 25  2020
# 26  2021

# %%
Forcasted_value = reg.predict(x_predict)

# %%
Forcasted_value
# Out:
# array([[ 6069.67856572],
#        [ 6923.78127862],
#        [ 7777.88399153],
#        [ 8631.98670444],
#        [ 9486.08941735],
#        [18027.11654644],
#        [18881.21925935],
#        [19735.32197226],
#        [20589.42468516],
#        [21443.52739807],
#        [22297.63011098],
#        [23151.73282389],
#        [24005.8355368 ],
#        [24859.93824971],
#        [25714.04096262],
#        [26568.14367552],
#        [34255.0680917 ],
#        [35109.17080461],
#        [35963.27351752],
#        [36817.37623043],
#        [37671.47894334],
#        [38525.58165625],
#        [39379.68436915],
#        [40233.78708206],
#        [41087.88979497],
#        [41941.99250788],
#        [42796.09522079]])

# %%
plt.scatter(x, y, color = 'blue')
plt.plot(x_predict, Forcasted_value, color = 'firebrick')

# %%
df_2["Forecast"] = Forcasted_value

# %%
df_2
# Out:
#     year      Forecast
# 0   1978   6069.678566
# 1   1979   6923.781279
# 2   1980   7777.883992
# 3   1981   8631.986704
# 4   1982   9486.089417
# 5   1992  18027.116546
# 6   1993  18881.219259
# 7   1994  19735.321972
# 8   1995  20589.424685
# 9   1996  21443.527398
# 10  1997  22297.630111
# 11  1998  23151.732824
# 12  1999  24005.835537
# 13  2000  24859.938250
# 14  2001  25714.040963
# 15  2002  26568.143676
# 16  2011  34255.068092
# 17  2012  35109.170805
# 18  2013  35963.273518
# 19  2014  36817.376230
# 20  2015  37671.478943
# 21  2016  38525.581656
# 22  2017  39379.684369
# 23  2018  40233.787082
# 24  2019  41087.889795
# 25  2020  41941.992508
# 26  2021  42796.095221

# %%
df_2.to_csv("Prediction.csv")
